# %% [markdown]
# # Dvouvrstvý perceptron s využitím autogradu

# %% [markdown]
# - Úkolem cvičení je natrénovat opět **dvouvrstvý perceptron** pro klasifikaci obrázků na datasetu CIFAR-10, **tentokrát ovšem za použití modulu `ans.autograd` z minulého cvičení**.
# - Vytvoříme novou třídu `ans.classification.TwoLayerPerceptronAutograd`, která bude obsahovat pouze dopředný průchod. Zpětný průchod zajistí automaticky implementace `ans.autograd.Variable.backprop` implementovaná v minulém cvičení.
# - Vytvoříme rovněž nový modul `ans.nn`, do kterého budeme postupně přidávat funkcionalitu související s neuronovými sítěmi, abychom nemuseli neustále opakovat shodné bloky kódu.
#
# **Poznámka**
# - Tento notebook nezapíná [autoreload extension](https://ipython.org/ipython-doc/3/config/extensions/autoreload.html), protože testování využívá type checking pomocí `isinstance` a [to při reloadu modulu selhává](https://github.com/ipython/ipython/issues/12399).
# - Při každé modifikaci modulu `ans.autograd` je proto bohužel nutné notebook restartovat a spustit celý kód znovu (např. "Run All") 😟

# %%
import sys
sys.path.append('..')  # import tests

import numpy as np
import matplotlib.pyplot as plt
import PIL
import torch
import torchvision
import ans
from tests import test_perceptron_autograd

# %% [markdown]
# # Příprava diferencovatelných operací

# %% [markdown]
# - Z minulého cvičení ma `Variable` implementované pouze operace `+`, `-`, `*` a `/`.
# - Pro vícevrstvý perceptron (viz cvičení [two_layer_perceptron](two_layer_perceptron.ipynb)) optimalizovaný softmax křížovou entropií budeme ještě potřebovat alespoň
#   - maticové násobení `@` pro vnitřní vrstvy perceptronu,
#   - nelinearitu `sigmoid`,
#   - `log`, `sum`, `exp` a `__getitem__` pro výpočet lossu.

# %% [markdown]
# ## Maticové násobení `z = x @ y`

# %% [markdown]
# - Budeme uvažovat pouze minimálně dvourozměrné tensory, tj. matice x matice a výše.
#
# **Dopředný průchod**
#
# $$\boldsymbol{z} = \boldsymbol{x} \cdot \boldsymbol{y}$$
#
# - $\boldsymbol{x} = [x_{\ldots,n,d}]$ je nejméně dvourozměrný tensor s rozměry $\ldots \times N \times D$,
# - $\boldsymbol{y} = [y_{\ldots,d,k}]$ je nejméně dvourozměrný tensor s rozměry $\ldots \times D \times K$,
# - $\boldsymbol{z} = [z_{\ldots,n,k}]$ je nejméně dvourozměrný tensor s rozměry $\ldots \times N \times K$,
#
# **Zpětný průchod**
#
# $$
# \begin{align*}
#     \overline{\boldsymbol{x}} &= \overline{\boldsymbol{z}} \cdot \boldsymbol{y}^\top \\
#     \overline{\boldsymbol{y}} &= \boldsymbol{x}^\top \cdot \overline{\boldsymbol{z}}
# \end{align*}
# $$
#
# - transpozicí $\boldsymbol{x}^\top$ pro vícerozměrné tensory se myslí prohození posledních dvou dimenzí $\ldots \times N \times D \rightarrow \ldots \times D \times N$
#
# **Bonus**
#
# - Zobecněte tak aby operátor `x @ y` fungoval i pro vektor (1D tensor) x matice a všechny ostatní kombinace podporované v PyTorchi.

# %% [markdown]
# ### TODO: implementujte operátory [`ans.autograd.Variable.__matmul__`](../ans/autograd.py) a [`ans.autograd.Variable.__rmatmul__`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestMatMul.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.107s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %%
test_perceptron_autograd.TestMatMulGeneral.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ERROR
#
# ======================================================================
# ERROR: test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../tests/test_autograd.py", line 89, in test_operation
#     dx, dy = z.grad_fn(dz)
#              ^^^^^^^^^^^^^
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../ans/autograd.py", line 247, in grad_fn
#     grad_self = dout @ other.data.mT if isinstance(other, Variable) else dout @ other.mT
#                        ^^^^^^^^^^^^^
# RuntimeError: tensor.mT is only supported on matrices or batches of matrices. Got 1-D tensor.
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.007s
#
# FAILED (errors=1)
# *** TEST PARAMS CONFIGURATION THAT FAILED ***
# x_shape=(2,), y_shape=(2,), dtype=torch.float32, device=cpu, x_type=<class 'ans.autograd.Variable'>, y_type=<class 'ans.autograd.Variable'>
# <unittest.runner.TextTestResult run=1 errors=1 failures=0>

# %% [markdown]
# ## Sigmoid `z = x.sigmoid()`

# %% [markdown]
# **Dopředný průchod**
#
# $$z = \frac{1}{1 + e^{-x}}$$
# - $x$ je reálné číslo (skalár)
# - $z$ je reálně číslo (skalár)
#
# **Zpětný průchod**
#
# Samostatně jako cvičení 😉

# %% [markdown]
# ### TODO: implementujte metodu [`ans.autograd.Variable.sigmoid`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestSigmoid.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.038s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Umocňování `z = x.exp()`

# %% [markdown]
# **Dopředný průchod**
#
# $$
# z = e^{x}
# $$
# - $x$ je reálné číslo (skalár)
# - $z$ je reálně číslo (skalár)
#
# **Zpětný průchod**
#
# Samostatně jako cvičení 😉

# %% [markdown]
# ### TODO: implementujte metodu [`ans.autograd.Variable.exp`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestExp.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.007s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Přirozený logaritmus `z = x.log()`

# %% [markdown]
# - Nutné pro výpočet křížové entropie, kde se loss počítá jako logaritmus z pravděpodobnosti predikované pro target třídu.
#
# **Dopředný průchod**
#
# $$
# z = \ln x
# $$
# - $x$ je reálné číslo (skalár)
# - $z$ je reálně číslo (skalár)
#
# **Zpětný průchod**
#
# Samostatně jako cvičení 😉

# %% [markdown]
# ### TODO: implementujte metodu [`ans.autograd.Variable.log`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestLog.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.013s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Výběr prvku `z = x[indices]`

# %% [markdown]
# - Nutné pro výpočet křížové entropie, kde se loss počítá jako $l = \ln \widehat{p}_y$, kde $\widehat{p}_y$ je pravděpodobnost predikovaná modelem pro target třídu $y$.
#
# **Dopředný průchod**
#
# - Operace je implementovaná v PyTorch jako `z = x[ids]`, kde `ids` může být `int`, `tuple[int,...]`, `list[int,...]` nebo `torch.Tensor`.
# - Operaci si zjednodušíme a výběr omezíme na podmnožinu prvků `x`, kde se navíc nemůže opakovat výběr stejného prvku.
# - Příklad:
#   ``` python
#   x = torch.tensor([0.5, 0.6, 0.7])
#   z = x[[0]]  # z = torch.tensor([0.5]) ... ok
#   z = x[[0, 1]]  # z = torch.tensor([0.5, 0.6]) ... ok
#   z = x[[0, 0]]  # z = torch.tensor([0.5, 0.5]) ... validni v PyTorch, ale zde pro jednoduchost neuvazujeme (opakuje se prvek 0)
#   z = x[[False, True, True]]  # z = torch.tensor([0.6, 0.7]) ... ok
#   z = x[:2]  # z = torch.tensor([0.5, 0.6]) ... ok
#   ...
#   ```
#
# **Zpětný průchod**
#
# - Lokální gradient na *vybrané* prvky je jedna.
# - Lokální gradient na *nevybrané* prvky je nula.

# %%
test_perceptron_autograd.TestGetItem.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.093s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Součet prvků `z = x.sum(dim=..., keepdim=...)`

# %% [markdown]
# - Nutné pro výpočet softmaxu, kdy potřebujeme součet přes pravděpodobnosti tříd.
#
# **Dopředný průchod**
#
# - Operace je implementovaná v PyTorch jako `z = x.sum(...)`
# - Podporované musí být oba parametry `dim` a `keepdim`, viz <https://pytorch.org/docs/stable/generated/torch.sum.html>
#
# **Zpětný průchod**
#
# - Lokální gradient na všechny prvky je jedna.

# %% [markdown]
# ### TODO: implementujte metodu [`ans.autograd.Variable.sum`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestSum.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.022s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## (Bonus) Průměr prvků `z = x.mean(dim=..., keepdim=...)`

# %% [markdown]
# - Podobné jako `x.sum(...)`, pouze s průměrem namísto součtu.

# %% [markdown]
# ### TODO: implementujte metodu [`ans.autograd.Variable.mean`](../ans/autograd.py)

# %%
test_perceptron_autograd.TestMean.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.021s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Třída `TwoLayerPerceptronAutograd`

# %% [markdown]
# - Cílem cvičení je natrénovat model dvouvrstvého perceptronu bez explicitního kódování zpětného průchodu, tj. s využitím autogradu.
# - Model bude imeplementovat třída `ans.classification.TwoLayerPerceptronAutograd`.
# - Parametry klasifikátoru budou reprezentovány jako `ans.autograd.Variable`, viz následující tabulku
#   | atribut   | typ                     | značení                                                            | rozměr       |
#   |-----------|-------------------------|--------------------------------------------------------------------|--------------|
#   | `weight1` | `ans.autograd.Variable` | $\boldsymbol{w}^{(1)} = \left[w_{d,h}^{(1)}\right]$                | $D \times H$ |
#   | `bias1`   | `ans.autograd.Variable` | $\boldsymbol{b}^{(1)} = \left[b_1^{(1)}, \ldots, b_H^{(1)}\right]$ | $H$          |
#   | `weight2` | `ans.autograd.Variable` | $\boldsymbol{w}^{(2)} = \left[w_{d,k}^{(2)}\right]$                | $H \times K$ |
#   | `bias2`   | `ans.autograd.Variable` | $\boldsymbol{b}^{(2)} = \left[b_1^{(2)}, \ldots, b_K^{(2)}\right]$ | $K$          |
# - Třída bude obsahovat pouze kód pro dopředný průchod (průchod sítí a výpočet lossu).
# - Zpětný průchod bude volán jako
#   ``` python
#   # vynulovani gradientu
#   ...
#   # zpetna propagace
#   loss.backprop()
#   ```
# - Po jeho provedení budou vyplněny atributy `.grad` všechny parametrů modelu, což umožní update pomocí SGD.
# - **Důležité je před každým zpětným průchodem vynulovat gradienty parametrů, aby nedocházelo k jejich akumulaci přes různé dávky (minibatche)**, viz např. <https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch>.
#
# **Funkce `softmax_cross_entropy`**
# - Výpočet lossu implementujte jako funkci `ans.classification.softmax_cross_entropy`, aby se nemusely opakovat stejné kusy kódu v `TwoLayerPerceptronAutograd.train_step` a `TwoLayerPerceptronAutograd.val_Step`.
# - Funkce by měla být agnostická vůči typu `logits` parametru:
#   - pokud je `torch.Tensor`, výsledný loss bude rovněž `torch.Tensor`,
#   - pokud je `Variable`, výsledný loss bude rovněž `Variable`.

# %% [markdown]
# ### TODO: implementuje funkci [`ans.classification.softmax_cross_entropy`](../ans/classification.py).

# %%
test_perceptron_autograd.TestSoftmaxCrossEntropy.eval()
# Out:
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
# test_sce (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_sce) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.011s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementuje metodu [`ans.classification.TwoLayerPerceptronAutograd.__init__`](../ans/classification.py).

# %%
test_perceptron_autograd.TestInit.eval()
# Out:
# test_init_params (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_init_params) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.015s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementuje funkci [`ans.classification.TwoLayerPerceptronAutograd.train_step`](../ans/classification.py).

# %%
test_perceptron_autograd.TestTrainStep.eval()
# Out:
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
# test_step (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_step) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementuje funkci [`ans.classification.TwoLayerPerceptronAutograd.val_step`](../ans/classification.py).

# %%
test_perceptron_autograd.TestValStep.eval()
# Out:
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
# test_step (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_step) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ## Preprocessing dat

# %% [markdown]
# - Pro trénování bude potřeba opět ještě preprocessing dat, podobně jako v minulých cvičeních.
# - Použijeme shodný preprocessing jako ve cvičeních [linear_classification](linear_classification.ipynb) a [two_two_layer_perceptron](two_layer_perceptron.ipynb), tj. zploštení obrázků do vektorů a převod hodnot pixelů 0..255 do rozsahu 0..1 prostým vydělením 255.

# %% [markdown]
# ### TODO: implementuje funkci `preprocess`.

# %%
def preprocess(img: PIL.Image) -> torch.Tensor:
    """
    Args:
        img: image of type PIL.Image
    Returns:
        x: 1-dimensional tensor; shape (num_pixels * num_channels,), dtype float32
    """
    
    one_dim_array = np.array(img).flatten()
    x = torch.tensor(one_dim_array, dtype=torch.float32) / 255
    
    return x

# %%
test_perceptron_autograd.TestPreprocess.eval(preprocess_fn=preprocess)
# Out:
# test_preprocess (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_preprocess) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.007s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Trénování klasifikátoru

# %% [markdown]
# - Pokud inicializujete parametry ve stejném pořadí a shodným způsobem jako ve cvičení [two_two_layer_perceptron](two_layer_perceptron.ipynb) (a pouze "obalíte" do `Variable`), měli byste dostat naprosto stejná čísla včetně progressu lossu!
# - Nejlepší model uložte jako
#   ``` python
#   model.save('../output/two_layer_perceptron_autograd_weights.pt')
#   ```

# %% [markdown]
# ### TODO: Natrénujte dvouvrstvý perceptron tak, aby dosáhl alespoň 45 % (bonusově 50 %) *validační* accuracy.

# %%
ans.utils.seed_everything(0)

########################################
# hyperparametry
batch_size = 20
learning_rate = 5e-3
num_epochs = 100

# dataset
train_dataset = torchvision.datasets.CIFAR10(root='../data', train=True, download=True, transform=preprocess)
val_dataset = torchvision.datasets.CIFAR10(root='../data', train=False, download=True, transform=preprocess)

# loadery
train_loader = ans.data.BatchLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = ans.data.BatchLoader(val_dataset, batch_size=batch_size, shuffle=False)

# model
in_size = 32 * 32 * 3  # CIFAR-10 image size (3 color channels, 32x32 pixels)
hidden_size = 256  # neurons
out_size = 10  # CIFAR-10 has 10 classes
model = ans.classification.TwoLayerPerceptron(in_size=in_size, hidden_size=hidden_size, out_size=out_size)

# validace pred trenovanim (sanity check, loss by mel byt cca 2.30)
train_loss, train_acc = ans.classification.validate(model, train_loader)
val_loss, val_acc = ans.classification.validate(model, val_loader)
print(f"after init: train_loss={train_loss:.5f}, train_acc={train_acc:.3f}, val_loss={val_loss:.5f}, val_acc={val_acc:.3f}")
best_val_acc = 0.0

for epoch in range(num_epochs):
    # Trainging
    train_loss, train_acc = ans.classification.train_epoch(model, train_loader, learning_rate=learning_rate)

    # Validation
    val_loss, val_acc = ans.classification.validate(model, val_loader)
    print(f"Epoch {epoch + 1}: train_loss={train_loss:.5f}, train_acc={train_acc:.3f}, val_loss={val_loss:.5f}, val_acc={val_acc:.3f}")

    # Save the best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        model.save('../output/two_layer_perceptron_autograd_weights.pt')

print(f"Training complete. Best validation accuracy achieved: {best_val_acc:.3f}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# after init: train_loss=2.30262, train_acc=0.100, val_loss=2.30262, val_acc=0.100
# Epoch 1: train_loss=2.30396, train_acc=0.104, val_loss=2.29390, val_acc=0.138
# Epoch 2: train_loss=2.22763, train_acc=0.155, val_loss=2.14385, val_acc=0.177
# Epoch 3: train_loss=2.10010, train_acc=0.204, val_loss=2.05773, val_acc=0.241
# Epoch 4: train_loss=2.02996, train_acc=0.248, val_loss=1.99706, val_acc=0.256
# Epoch 5: train_loss=1.97887, train_acc=0.271, val_loss=1.95510, val_acc=0.287
# Epoch 6: train_loss=1.94444, train_acc=0.292, val_loss=1.93075, val_acc=0.292
# Epoch 7: train_loss=1.92191, train_acc=0.305, val_loss=1.90565, val_acc=0.310
# Epoch 8: train_loss=1.90346, train_acc=0.316, val_loss=1.89358, val_acc=0.312
# Epoch 9: train_loss=1.88482, train_acc=0.325, val_loss=1.87120, val_acc=0.335
# Epoch 10: train_loss=1.86562, train_acc=0.334, val_loss=1.85106, val_acc=0.341
# Epoch 11: train_loss=1.84701, train_acc=0.342, val_loss=1.83605, val_acc=0.347
# Epoch 12: train_loss=1.83116, train_acc=0.349, val_loss=1.82083, val_acc=0.347
# Epoch 13: train_loss=1.81774, train_acc=0.355, val_loss=1.80587, val_acc=0.356
# Epoch 14: train_loss=1.80530, train_acc=0.357, val_loss=1.79802, val_acc=0.364
# Epoch 15: train_loss=1.79375, train_acc=0.363, val_loss=1.78389, val_acc=0.366
# Epoch 16: train_loss=1.78273, train_acc=0.366, val_loss=1.77376, val_acc=0.369
# Epoch 17: train_loss=1.77175, train_acc=0.372, val_loss=1.76310, val_acc=0.377
# Epoch 18: train_loss=1.76085, train_acc=0.377, val_loss=1.75078, val_acc=0.380
# Epoch 19: train_loss=1.74996, train_acc=0.381, val_loss=1.73800, val_acc=0.383
# Epoch 20: train_loss=1.73930, train_acc=0.384, val_loss=1.73153, val_acc=0.383
# Epoch 21: train_loss=1.72816, train_acc=0.391, val_loss=1.72035, val_acc=0.392
# Epoch 22: train_loss=1.71858, train_acc=0.394, val_loss=1.70953, val_acc=0.399
# Epoch 23: train_loss=1.70858, train_acc=0.396, val_loss=1.70216, val_acc=0.404
# Epoch 24: train_loss=1.69822, train_acc=0.401, val_loss=1.69571, val_acc=0.403
# Epoch 25: train_loss=1.68889, train_acc=0.405, val_loss=1.68426, val_acc=0.406
# Epoch 26: train_loss=1.67987, train_acc=0.409, val_loss=1.67282, val_acc=0.408
# Epoch 27: train_loss=1.67064, train_acc=0.412, val_loss=1.66827, val_acc=0.413
# Epoch 28: train_loss=1.66197, train_acc=0.416, val_loss=1.65569, val_acc=0.416
# Epoch 29: train_loss=1.65263, train_acc=0.420, val_loss=1.65533, val_acc=0.417
# Epoch 30: train_loss=1.64451, train_acc=0.422, val_loss=1.65343, val_acc=0.411
# Epoch 31: train_loss=1.63669, train_acc=0.426, val_loss=1.63234, val_acc=0.428
# Epoch 32: train_loss=1.62939, train_acc=0.429, val_loss=1.62643, val_acc=0.424
# Epoch 33: train_loss=1.62119, train_acc=0.432, val_loss=1.62017, val_acc=0.430
# Epoch 34: train_loss=1.61322, train_acc=0.436, val_loss=1.61222, val_acc=0.434
# Epoch 35: train_loss=1.60691, train_acc=0.436, val_loss=1.61117, val_acc=0.432
# Epoch 36: train_loss=1.59942, train_acc=0.440, val_loss=1.60075, val_acc=0.438
# Epoch 37: train_loss=1.59301, train_acc=0.443, val_loss=1.60746, val_acc=0.434
# Epoch 38: train_loss=1.58649, train_acc=0.445, val_loss=1.59005, val_acc=0.440
# Epoch 39: train_loss=1.57956, train_acc=0.447, val_loss=1.58550, val_acc=0.444
# Epoch 40: train_loss=1.57468, train_acc=0.449, val_loss=1.58074, val_acc=0.444
# Epoch 41: train_loss=1.56826, train_acc=0.451, val_loss=1.57922, val_acc=0.443
# Epoch 42: train_loss=1.56208, train_acc=0.453, val_loss=1.57301, val_acc=0.446
# Epoch 43: train_loss=1.55571, train_acc=0.455, val_loss=1.57076, val_acc=0.445
# Epoch 44: train_loss=1.55059, train_acc=0.458, val_loss=1.56541, val_acc=0.455
# Epoch 45: train_loss=1.54493, train_acc=0.460, val_loss=1.55516, val_acc=0.453
# Epoch 46: train_loss=1.53914, train_acc=0.461, val_loss=1.56770, val_acc=0.443
# Epoch 47: train_loss=1.53434, train_acc=0.463, val_loss=1.54878, val_acc=0.455
# Epoch 48: train_loss=1.52900, train_acc=0.467, val_loss=1.54520, val_acc=0.457
# Epoch 49: train_loss=1.52326, train_acc=0.467, val_loss=1.54734, val_acc=0.452
# Epoch 50: train_loss=1.51756, train_acc=0.470, val_loss=1.54014, val_acc=0.459
# Epoch 51: train_loss=1.51214, train_acc=0.472, val_loss=1.53593, val_acc=0.460
# Epoch 52: train_loss=1.50755, train_acc=0.474, val_loss=1.53812, val_acc=0.457
# Epoch 53: train_loss=1.50280, train_acc=0.473, val_loss=1.53252, val_acc=0.462
# Epoch 54: train_loss=1.49721, train_acc=0.477, val_loss=1.52460, val_acc=0.463
# Epoch 55: train_loss=1.49252, train_acc=0.478, val_loss=1.52548, val_acc=0.461
# Epoch 56: train_loss=1.48698, train_acc=0.480, val_loss=1.53230, val_acc=0.465
# Epoch 57: train_loss=1.48230, train_acc=0.482, val_loss=1.52332, val_acc=0.463
# Epoch 58: train_loss=1.47749, train_acc=0.484, val_loss=1.51561, val_acc=0.465
# Epoch 59: train_loss=1.47273, train_acc=0.485, val_loss=1.50876, val_acc=0.472
# Epoch 60: train_loss=1.46830, train_acc=0.487, val_loss=1.50266, val_acc=0.470
# Epoch 61: train_loss=1.46360, train_acc=0.487, val_loss=1.50304, val_acc=0.469
# Epoch 62: train_loss=1.45868, train_acc=0.490, val_loss=1.50258, val_acc=0.473
# Epoch 63: train_loss=1.45486, train_acc=0.492, val_loss=1.49910, val_acc=0.472
# Epoch 64: train_loss=1.44999, train_acc=0.493, val_loss=1.50819, val_acc=0.465
# Epoch 65: train_loss=1.44634, train_acc=0.495, val_loss=1.48991, val_acc=0.475
# Epoch 66: train_loss=1.44224, train_acc=0.498, val_loss=1.48678, val_acc=0.476
# Epoch 67: train_loss=1.43724, train_acc=0.496, val_loss=1.48540, val_acc=0.477
# Epoch 68: train_loss=1.43340, train_acc=0.499, val_loss=1.48035, val_acc=0.478
# Epoch 69: train_loss=1.42895, train_acc=0.501, val_loss=1.47958, val_acc=0.479
# Epoch 70: train_loss=1.42517, train_acc=0.501, val_loss=1.48073, val_acc=0.478
# Epoch 71: train_loss=1.42160, train_acc=0.504, val_loss=1.47474, val_acc=0.478
# Epoch 72: train_loss=1.41738, train_acc=0.503, val_loss=1.47113, val_acc=0.478
# Epoch 73: train_loss=1.41393, train_acc=0.506, val_loss=1.46819, val_acc=0.482
# Epoch 74: train_loss=1.40984, train_acc=0.505, val_loss=1.46523, val_acc=0.479
# Epoch 75: train_loss=1.40623, train_acc=0.506, val_loss=1.46550, val_acc=0.482
# Epoch 76: train_loss=1.40210, train_acc=0.510, val_loss=1.46386, val_acc=0.483
# Epoch 77: train_loss=1.39896, train_acc=0.511, val_loss=1.46808, val_acc=0.483
# Epoch 78: train_loss=1.39462, train_acc=0.511, val_loss=1.45869, val_acc=0.481
# Epoch 79: train_loss=1.39088, train_acc=0.512, val_loss=1.46289, val_acc=0.480
# Epoch 80: train_loss=1.38718, train_acc=0.516, val_loss=1.46281, val_acc=0.483
# Epoch 81: train_loss=1.38318, train_acc=0.515, val_loss=1.46689, val_acc=0.478
# Epoch 82: train_loss=1.37978, train_acc=0.517, val_loss=1.45821, val_acc=0.485
# Epoch 83: train_loss=1.37631, train_acc=0.518, val_loss=1.45773, val_acc=0.482
# Epoch 84: train_loss=1.37318, train_acc=0.518, val_loss=1.45030, val_acc=0.485
# Epoch 85: train_loss=1.37039, train_acc=0.521, val_loss=1.44405, val_acc=0.491
# Epoch 86: train_loss=1.36658, train_acc=0.520, val_loss=1.43861, val_acc=0.491
# Epoch 87: train_loss=1.36264, train_acc=0.522, val_loss=1.44344, val_acc=0.492
# Epoch 88: train_loss=1.35902, train_acc=0.524, val_loss=1.44230, val_acc=0.491
# Epoch 89: train_loss=1.35609, train_acc=0.525, val_loss=1.43291, val_acc=0.496
# Epoch 90: train_loss=1.35276, train_acc=0.526, val_loss=1.43857, val_acc=0.486
# Epoch 91: train_loss=1.34898, train_acc=0.527, val_loss=1.42998, val_acc=0.496
# Epoch 92: train_loss=1.34494, train_acc=0.527, val_loss=1.42887, val_acc=0.497
# Epoch 93: train_loss=1.34196, train_acc=0.530, val_loss=1.42537, val_acc=0.498
# Epoch 94: train_loss=1.33875, train_acc=0.532, val_loss=1.42624, val_acc=0.496
# Epoch 95: train_loss=1.33535, train_acc=0.531, val_loss=1.42483, val_acc=0.498
# Epoch 96: train_loss=1.33234, train_acc=0.534, val_loss=1.43524, val_acc=0.496
# Epoch 97: train_loss=1.32904, train_acc=0.535, val_loss=1.43140, val_acc=0.490
# Epoch 98: train_loss=1.32565, train_acc=0.534, val_loss=1.41563, val_acc=0.501
# Epoch 99: train_loss=1.32172, train_acc=0.536, val_loss=1.42203, val_acc=0.494
# Epoch 100: train_loss=1.31963, train_acc=0.537, val_loss=1.41654, val_acc=0.500
# Training complete. Best validation accuracy achieved: 0.501

# %%
test_perceptron_autograd.TestValAccuracy45.eval(preprocess_fn=preprocess)
# Out:
# test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 7.112s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %%
test_perceptron_autograd.TestValAccuracy50.eval(preprocess_fn=preprocess)
# Out:
# test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 7.397s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>
