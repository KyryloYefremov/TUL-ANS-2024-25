# %% [markdown]
# # Klasifikace obrázků CIFAR-10 pomocí konvoluční sítě

# %% [markdown]
# - Úkolem cvičení je natrénovat konvoluční síť pro klasifikaci na datasetu CIFAR-10 s alespoň 75% úpěšností na validační sadě.
# - Nejprve implementujeme konvoluci jako diferencovatelnou operaci a vrstvu.
# - Poté přidáme max-pooling a reshape.
# - Z těchto funkčních bloků nakonec sestavíme konvoluční síť.
# - Dobře navržená síť dosáhne i přes 90 % validační accuracy.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')  # import tests

# import os
# os.chdir('/content/TUL-ANS-2024-25/')

import torch
import torchvision

import ans
from tests import test_convolution

# %%
torch.set_printoptions(profile='short')

# %% [markdown]
# # Dvourozměrná konvoluce jako diferencovatelná operace

# %% [markdown]
# - Konvoluci implementujeme jako `ans.nn.Function` i jako `ans.nn.Module`.
#
# **Parametry**
#
# | atribut  | typ                               | značení          | rozměr                         | poznámka                                             |
# |----------|-----------------------------------|------------------|--------------------------------|------------------------------------------------------|
# | `weight` | `ans.autograd.Variable`           | $\boldsymbol{w}$ | $F \times C \times K \times K$ | `num_filters x in_chnls x kernel_size x kernel_size` |
# | `bias`   | `Optional[ans.autograd.Variable]` | $\boldsymbol{b}$ | $F$                            | nepovinný                                            |
#
# **Inicializace**
#
# - *Váhy* inicializujte opět uniformní variantou Xavier/Glorot/Kaiming/He, tak, [jak je tomu v knihovně v PyTorch](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html)
#   $$
#   w_{f,c,i,j} \sim \mathcal{U}\left(\frac{-1}{\sqrt{C\cdot K^2}}, \frac{+1}{\sqrt{C\cdot K^2}}\right)
#   $$
# - *Bias* bude *nepovinný* parametr a příp. jej inicializujeme na nuly. Výsledný vektor musí být atribut typu `Variable`, příp. objekt `None`, pokud je do `__init__` předáno `bias=False`.
#
# **Dopředný průchod**
#
# $$
# \boldsymbol{z}_n = \textrm{conv2}\left( \boldsymbol{x}_n, \boldsymbol{w}, \boldsymbol{b}; S, P, D \right)
# $$
# kde
# - $\boldsymbol{x}_n$ je $n$-tý "obrázek" dávky jako tensor s rozměry $C \times H \times W$
# - $S$ (hyperparametr) je krok (stride)
# - $P$ (hyperparametr) je padding
# - $D$ (hyperparametr) je dilation
# - $\boldsymbol{z}_n$ je $n$-tý výstup dávky jako tensor s rozměry $F \times H' \times W'$
# - Pro rozměr výstupu $W'$ platí
#   $$
#   W' = \left\lfloor \frac{W + 2 \cdot P - K}{S} \right\rfloor + 1
#   $$
#
# **Zpětný průchod**
# $$
# \begin{split}
#     \overline{\boldsymbol{x}}_n & = \textrm{conv2}^\top(\overline{\boldsymbol{z}}_n, \boldsymbol{w}, \boldsymbol{0}; S, P, D) \\
#     \boldsymbol{\overline{w}}_{f,c} & = \sum_{n=1}^N{ \textrm{conv2}(\boldsymbol{x}_{n,c}, \overline{\boldsymbol{z}}_{n,f}, \boldsymbol{0}; D, P, S) }
# \end{split}
# $$
# - kde
#   - $\textrm{conv2}^\top(\cdot)$ je tzv. transponovaná dvourozměrná konvoluce
#   - $\boldsymbol{x}_{n,c}$ je $c$-tý kanál $n$-tého vstupu jako matice s rozměry $H \times W$
#   - $\overline{\boldsymbol{z}}_{n,f}$ je příchozí gradient na $f$-tý kanál $n$-tého výstupu jako tensor s rozměry $H' \times W'$
#   - $\boldsymbol{\overline{w}}_{f,c}$ je vypočítáný gradient na $c$-tý kanál $f$-tého filtru jako matice s rozměry $K \times K$
#
# **Implementace**
#
# - Vzhledem k výpočetní náročnosti nebudeme funkce $\textrm{conv2}(\cdot)$ a $\textrm{conv2}^\top(\cdot)$ implementovat vlastními silami pomocí for cyklů ani komplikovaného broadcastingu, ale použijeme funkce `conv2d`, resp. `conv_transpose2d` modulu `torch.nn.functional` knihovny Pytorch.
# - Není to vyžadováno, ale gradient na váhy $\boldsymbol{\overline{w}}$ lze získat i zcela bez použití cyklů (pro `groups=1`).
#
# **Output padding u `conv_transpose2d` pro výpočet gradientu na vstup $\overline{\boldsymbol{x}}_n$**
#
# - Pokud je stride $S \gt 1$, může se stát, že z různě velkých vstupů $\boldsymbol{x}_n$, $\boldsymbol{x}_m$ funkcí vzniknou stejně velké výstupy $\boldsymbol{z}_n$, resp. $\boldsymbol{z}_m$.
# - Pokud potom použijeme $\textrm{conv2}^\top$ jako zpětný průchod pro výpočet gradientu na vstup $\overline{\boldsymbol{x}}_n$, není rozměr výsledného gradientu na vstup jednoznačně určená, a tak $\overline{\boldsymbol{x}}_n$ nemusí svou velikostí přesně odpovídat $\boldsymbol{x}$.
# - Funkce `torch.nn.conv_transpose2d` proto zavádí argument `output_padding`, který výstup nastaví o požadovanou hodnotu.
# - Aby měl $\overline{\boldsymbol{x}}_n$ rozměry shodné s $\boldsymbol{x}_n$ a procházely všechny testy, je nutné `output_padding` dopočítat jako
#   $$
#   \begin{split}
#     O_x &= W - (W' - 1) \cdot S + 2 \cdot P - (K - 1) \cdot D - 1 \\
#     O_y &= H - (H' - 1) \cdot S + 2 \cdot P - (K - 1) \cdot D - 1
#   \end{split}
#   $$
#
# **Oříznutí gradientu na váhy $\boldsymbol{\overline{w}}$**
#
# - Může se stát, že výstup konvoluce $\boldsymbol{\overline{w}}_{f,c} = \textrm{conv2}(\boldsymbol{x}_{n,c}, \overline{\boldsymbol{z}}_{n,f}, \ldots)$ vyjde větší než $K \times K$.
# - V takovém případě stačí výsledek o přebytečné hodnoty "zdola" a "zprava" oříznout.

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.Conv2d`

# %%
test_convolution.TestConv2dFunction.eval()
# Out:
# test_function (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_function) ... ok
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.081s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %%
test_convolution.TestConv2dFunctionOptional.eval()
# Out:
# test_function (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_function) ... FAIL
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
#
# ======================================================================
# FAIL: test_function (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_function)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../tests/test_neural_library.py", line 339, in test_function
#     self.check_backward_pass(inp_vars, z_var, z)
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../tests/test_neural_library.py", line 329, in check_backward_pass
#     self.check_grads(inp_vars)
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../tests/test_neural_library.py", line 316, in check_grads
#     self.assertTensorsClose(in_var.grad, in_var.data.grad, msg=msg)
#   File "/Users/kirillefremov/development/PycharmProjects/TUL-ANS-2024-25/assignments/../tests/__init__.py", line 112, in assertTensorsClose
#     self.fail(msg=f"{msg}\n{err_str}")
# AssertionError: dw
# The values for attribute 'shape' do not match: torch.Size([8, 4, 5, 5]) != torch.Size([8, 2, 5, 5]).
#
# Actual
# tensor([[[[-6.16e+00,  4.16e+01,  2.97e+00, -1.69e+01, -3.20e+01],
#           [ 2.11e+00, -6.77e+00,  1.20e+01, -2.37e+01,  1.53e+01],
#           [ 1.03e+01,  3.57e+01,  9.68e-01, -2.18e+01, -4.06e+01],
#           [ 8.14e+00,  3.76e+01,  9.40e+00, -1.03e+01,  1.73e+01],
#           [ 1.85e+01,  6.65e+01, -2.31e+01,  9.88e+00,  1.68e+01]],
#
#          [[-2.84e+01, -7.45e-01,  3.25e+01, -8.37e+00, -9.16e+00],
#           [-2.67e+01, -4.14e+00,  5.15e+00, -1.19e+01, -9.12e+00],
#           [-8.29e-01,  3.24e+01, -4.35e+01, -3.58e+01, -3.26e+01],
#           [ 2.76e+01,  3.12e+00,  1.73e+01, -3.59e+00, -8.37e+00],
#           [-6.26e+00,  4.66e+00, -9.98e-01, -3.20e+00,  2.19e+01]],
#
#          [[-1.57e+01,  3.09e+01,  9.79e+00, -1.17e+01, -1.95e+01],
#           [ 5.02e-01,  1.12e+01,  9.02e-01, -1.65e+01,  1.31e+00],
#           [ 7.61e+00,  2.65e+01,  2.46e+01, -4.40e+00, -2.18e+00],
#           [-1.05e+01,  1.73e+01, -2.99e+01, -6.04e+00,  4.34e+01],
#           [-2.21e+01, -1.17e+00,  2.98e+01, -1.82e+01, -1.74e+01]],
#
#          [[-5.27e+00,  2.32e+01,  1.70e+01, -2.30e+01, -2.74e+00],
#           [-1.16e+01,  5.25e+01,  1.54e+01, -1.33e+01,  4.12e+01],
#           [-8.56e+00, -2.68e+01,  2.02e+01, -2.10e+01,  1.02e+01],
#           [-2.51e+01,  1.13e+01,  2.40e+01, -1.74e+01, -9.39e+00],
#           [-4.29e+01, -7.23e+00,  6.41e+00,  2.18e+01, -2.97e+01]]],
#
#
#         [[[-1.27e+01,  2.04e+00,  1.20e+00,  3.94e+00,  1.91e+01],
#           [ 1.09e+01,  2.20e+00,  1.61e+01, -2.70e+01, -1.78e+01],
#           [ 1.20e+01,  3.79e+00, -1.28e+01,  1.02e+00, -2.46e+01],
#           [ 2.31e+01, -3.55e+01,  1.09e+01, -3.09e+01,  5.41e+00],
#           [ 8.28e+00, -7.99e+00,  3.84e+00,  3.70e+01,  3.06e+01]],
#
#          [[ 3.84e+01,  1.27e+01,  7.62e+00, -4.79e+00,  1.91e+01],
#           [ 1.03e+00, -1.33e+01,  4.45e+01,  1.33e+01,  1.16e+01],
#           [ 1.95e+01,  1.70e+01,  1.85e+01, -1.65e+01, -1.35e+01],
#           [ 1.68e+01, -3.94e+01,  1.80e+01, -8.52e+00,  1.71e+01],
#           [-4.01e+01, -2.26e+01, -3.57e+01,  3.21e+00, -3.06e+01]],
#
#          [[ 4.61e+00,  2.25e+00,  2.78e+01,  1.91e+01, -2.34e+01],
#           [-2.74e+00,  9.36e+00, -1.09e+01,  3.34e+00,  1.09e+01],
#           [ 7.03e+00,  2.13e+01,  9.73e+00,  4.20e+01, -1.96e+01],
#           [-3.77e+01, -1.44e+01, -7.03e+01, -1.97e+01, -4.99e+01],
#           [-4.45e+00, -2.03e+01,  1.78e+01, -5.14e+00,  1.14e+01]],
#
#          [[-1.53e+01,  8.50e+00, -3.33e+00,  5.77e+01,  3.61e+00],
#           [-5.92e+00,  3.17e+01,  1.27e+00, -2.27e+00, -1.23e+01],
#           [ 3.71e+01,  2.20e+00, -1.33e+01, -1.75e+01, -1.59e+01],
#           [-2.03e+00, -2.56e+00, -3.46e+01,  7.53e+00, -9.17e+00],
#           [ 1.62e+01,  9.32e+00,  1.13e+01,  9.50e+00,  9.50e+00]]],
#
#
#         [[[ 2.18e+01,  1.01e+01,  1.57e+01,  1.84e+01,  1.73e+01],
#           [-1.58e+01,  1.33e+01, -6.99e+00,  1.56e+01,  2.90e+00],
#           [-2.93e+01, -2.39e+00, -9.08e-01,  4.75e+00, -1.70e+01],
#           [-3.41e+01,  4.11e+00, -1.03e+01, -2.76e+00,  8.64e+00],
#           [-1.47e+01,  1.16e+01, -3.39e+01,  3.92e+01,  3.73e+00]],
#
#          [[ 1.08e+01,  8.92e+00, -1.08e+01,  6.58e+00,  2.75e+01],
#           [ 1.60e+01,  5.21e+01, -8.04e+00,  3.58e+01, -3.33e+00],
#           [-1.02e+01, -3.23e+01,  1.93e+01,  2.74e+00,  3.06e+01],
#           [ 1.90e+01,  8.07e+00, -9.17e+00, -1.13e+01, -2.99e+01],
#           [ 3.08e+00, -8.45e+00, -1.57e+01, -2.94e+01, -1.74e+01]],
#
#          [[ 3.06e+01,  3.14e+01,  1.12e+01, -1.86e+01,  2.09e+00],
#           [-2.29e+01,  9.64e-01, -1.27e+01, -3.93e+01,  1.62e+00],
#           [-2.78e+01,  3.50e+01, -1.72e+01,  1.26e+01,  3.73e+00],
#           [ 3.35e+01,  5.26e+01,  1.65e+01, -8.00e+00, -1.43e+01],
#           [-2.55e+00,  3.36e+00,  4.59e+00, -6.12e+00,  2.92e+01]],
#
#          [[-3.22e+01, -9.36e-01,  1.29e+01,  2.38e+01, -2.94e+01],
#           [ 4.30e+00,  2.75e+01,  9.16e+00,  3.10e+01, -1.43e+01],
#           [ 4.93e+01,  4.57e+00, -6.46e+00, -1.47e+01,  9.93e+00],
#           [ 1.10e+01,  2.77e+01,  4.98e+00, -5.68e+01, -3.30e+01],
#           [-5.70e+00, -2.68e+01,  1.65e+00, -2.02e+01, -6.19e+00]]],
#
#
#         [[[-2.36e+01, -9.39e+00,  6.55e+01,  2.88e+01,  8.24e+00],
#           [ 5.79e+00,  1.02e+01, -8.27e+00, -3.34e+01, -1.58e+01],
#           [ 2.65e+01,  1.37e+01,  3.14e+00,  3.92e+01,  8.72e+00],
#           [ 2.62e+00, -1.07e+01,  4.21e+00,  1.37e+01,  3.13e+00],
#           [-1.15e+01, -3.38e+01, -8.28e+00, -3.34e+01, -3.07e+01]],
#
#          [[ 3.08e+00,  6.21e+00, -1.29e+01, -1.82e-01, -1.85e+01],
#           [ 6.15e-01, -1.94e+01, -5.18e+00,  2.37e+00,  1.00e+01],
#           [ 2.40e+01,  4.91e+01,  6.74e+00,  6.50e+00, -1.96e+01],
#           [-2.52e+01, -3.72e+00,  3.63e+01, -1.21e+01,  4.59e+01],
#           [-3.89e+00, -6.68e+00,  2.51e+00, -6.01e+00, -2.66e+00]],
#
#          [[ 3.41e+01,  4.10e+01,  4.84e+01,  7.03e+00,  2.37e+01],
#           [-3.42e+00, -8.64e+00, -1.85e+01,  2.70e+01, -1.68e+01],
#           [-1.87e+01,  2.96e+00,  3.08e+01,  5.27e+00,  8.04e-01],
#           [-1.38e+01,  4.27e+00,  1.18e+01, -1.55e+01, -2.07e+01],
#           [ 4.48e-01,  2.54e+01,  9.50e+00, -3.82e+01, -4.50e-02]],
#
#          [[-1.11e+01, -1.24e+00,  1.92e+01,  9.41e+00,  1.97e+01],
#           [-2.88e+01, -4.09e+01, -8.38e+00, -7.85e+00, -4.22e+01],
#           [-1.78e+01, -1.45e+01,  2.28e+00, -2.33e+01, -2.02e+01],
#           [ 2.97e+01,  3.43e+00, -1.88e+01,  2.31e+01,  2.05e+00],
#           [-9.00e+00,  1.97e+01,  2.49e+00, -1.56e+01,  9.74e+00]]],
#
#
#         [[[ 1.96e+01,  1.28e+01, -5.30e+00,  8.71e+00, -2.68e+01],
#           [-2.16e+00,  3.08e+01, -1.35e+00, -3.20e+01,  1.73e+01],
#           [ 3.21e+01,  2.40e+01,  2.20e+01, -1.69e+01,  3.14e+01],
#           [-1.48e+01,  3.61e+00,  2.99e+01,  1.06e+01, -2.29e+01],
#           [-1.90e+00,  1.30e+01, -1.50e+01, -2.36e+01,  5.29e+00]],
#
#          [[-2.40e+01, -3.65e+01,  8.69e-01, -4.66e+01, -3.37e+00],
#           [ 1.99e+00,  1.06e+01,  1.66e+01,  6.37e+00,  2.65e+01],
#           [ 3.16e+00, -2.34e+00, -5.57e+01, -1.35e+01, -3.55e+01],
#           [ 1.19e+01, -1.10e+01, -5.02e-01, -7.94e+00, -2.46e+01],
#           [ 1.12e+01,  1.20e+01, -2.22e+01, -6.16e+00, -1.01e+01]],
#
#          [[-3.48e+01,  1.75e+01, -5.21e+00,  5.19e-01, -2.15e+01],
#           [-5.70e+00,  1.12e+01,  2.34e+01,  1.04e+01,  3.94e+01],
#           [ 3.26e+01,  1.21e+01, -7.31e+00, -2.20e+01, -2.81e+01],
#           [-1.79e+00,  3.90e+01,  1.69e+01, -3.16e+00, -3.91e+01],
#           [ 9.21e+00, -3.81e+01, -3.76e+01,  2.45e+01,  2.27e+01]],
#
#          [[ 7.53e+00,  3.71e+00,  1.87e+01, -2.89e+01, -2.15e+01],
#           [ 1.73e+01, -3.54e+00,  5.24e+01,  1.15e+01,  1.62e+01],
#           [ 2.52e+01, -4.20e+01,  2.57e+01, -2.81e+00, -3.75e+01],
#           [ 2.08e+01, -5.05e+01, -3.32e+01, -8.57e+00, -2.64e-01],
#           [-1.25e+01,  1.75e+01, -3.40e+00,  2.88e+01, -1.82e+00]]],
#
#
#         [[[-1.27e+00, -2.12e+01, -8.99e+00,  2.61e+01, -1.47e+01],
#           [-1.74e+00, -1.42e+01, -8.78e+00,  3.15e+01,  5.80e+00],
#           [-1.43e+01, -2.12e+01, -1.73e+01,  1.97e+01, -1.25e+01],
#           [ 2.30e+01,  3.88e-01, -1.04e+01,  4.02e+00,  5.04e+01],
#           [-2.80e+01,  1.25e-01,  2.23e+01, -1.37e+01,  1.20e+01]],
#
#          [[-3.55e+01,  1.00e+01,  2.39e+01,  5.31e+00,  1.11e+01],
#           [-2.23e+01,  1.56e+01,  3.74e+01,  3.57e+01, -1.51e+01],
#           [-3.03e+01,  2.57e+01,  2.20e+00,  2.60e+01,  2.75e+01],
#           [ 2.33e+00, -4.15e+01, -2.76e+01, -4.70e+01,  5.43e+00],
#           [-2.91e+01,  1.29e+01, -1.99e+01, -2.61e+01, -8.95e+00]],
#
#          [[-1.95e+00, -9.06e+00,  1.30e+01,  2.04e+00, -4.70e+00],
#           [ 2.32e+01,  1.44e+01,  1.49e+01,  2.03e+01,  1.27e+01],
#           [-3.46e+01,  7.27e+00,  1.15e+00,  1.75e+00,  1.24e+01],
#           [-1.64e+01,  8.99e-02, -2.44e+01,  2.81e+01,  2.61e+01],
#           [-4.18e+01, -1.72e+01, -3.12e+01, -2.02e+01,  6.08e+00]],
#
#          [[-3.79e+00,  3.21e+00,  4.03e+01, -3.24e+01,  3.47e+01],
#           [-3.68e+00,  1.02e+01, -6.05e+01,  1.18e+01, -4.76e+00],
#           [-3.63e+01,  4.37e+01, -7.19e+00,  1.40e+01, -4.14e+01],
#           [-2.93e+01, -1.66e+01,  2.83e+00, -3.20e+01,  2.34e+01],
#           [ 1.68e+01, -1.30e+01, -1.58e+00,  2.77e+01,  1.15e+01]]],
#
#
#         [[[-2.93e+01,  2.86e+01, -2.42e+01, -1.32e+01, -1.58e+01],
#           [ 1.12e+01,  7.02e-01, -3.35e+00, -3.48e+01,  2.80e+01],
#           [ 3.07e+01, -1.19e+01, -2.06e+01,  2.43e+01,  1.42e+01],
#           [-1.28e+01,  1.14e+00, -1.07e+01,  9.80e+00, -3.07e+00],
#           [-8.26e-01,  1.72e+01,  1.44e+01,  1.49e+01, -1.75e+00]],
#
#          [[ 2.22e+01,  2.40e+01, -1.28e+01,  1.51e+01, -1.99e+01],
#           [ 2.99e+01,  1.57e+01,  4.79e+01,  2.07e+00, -2.20e+00],
#           [ 2.98e+01,  3.45e+01, -1.94e+00,  3.61e+01, -1.25e+00],
#           [ 1.58e+01,  2.25e+01,  2.08e+01,  4.43e+00, -5.28e+01],
#           [ 2.64e+01,  1.10e+01, -9.42e+00,  1.25e+01,  7.58e+00]],
#
#          [[ 1.71e+01, -2.23e+00, -7.56e+00, -3.14e+00, -5.35e-01],
#           [-2.67e+01,  1.35e+01,  1.01e+00, -3.57e+00, -2.72e+01],
#           [-2.21e+01,  1.85e+01, -2.09e+01, -5.98e+01, -2.93e+01],
#           [-1.40e+01,  3.90e+01,  1.11e+01,  1.35e+01, -6.67e+00],
#           [-7.60e+00, -6.58e+00,  4.93e+00, -2.35e+01,  3.92e+01]],
#
#          [[ 1.94e+01,  5.44e+00,  6.75e+00,  2.17e+01, -8.82e+00],
#           [-1.26e+01,  3.27e+01, -7.96e+00,  1.67e+01, -1.68e+01],
#           [-3.30e+01, -4.03e+01, -3.43e+01, -7.68e+00, -1.27e+01],
#           [-3.66e+00,  2.46e+01,  4.02e+01,  1.09e+01,  5.21e+00],
#           [-1.89e+01,  1.72e+01, -5.21e+01, -4.60e+01,  2.34e+00]]],
#
#
#         [[[ 2.91e+01,  2.58e+01, -2.32e+01, -4.36e-01, -6.35e+00],
#           [ 5.16e+00, -1.51e+01, -4.34e+01,  5.20e+01, -8.73e+00],
#           [-2.43e+01, -1.62e+01, -1.95e+01,  3.38e+01, -4.10e+00],
#           [ 3.53e+01, -4.45e+00, -1.90e+01,  1.33e+01,  2.22e+01],
#           [-2.90e+01, -5.22e+00,  1.86e+01,  1.72e+00, -4.93e+00]],
#
#          [[-9.50e+00,  2.29e+01,  4.04e+01,  1.59e+01, -1.41e+01],
#           [-7.81e+00,  1.08e-02, -5.61e+01, -7.28e+00,  2.14e+01],
#           [-5.07e+00, -2.33e+01, -2.31e+01,  2.66e+01,  1.15e+01],
#           [ 4.05e+01,  2.62e+01, -3.54e+01, -2.28e+01, -6.95e+00],
#           [-4.36e+01,  1.70e+00,  1.59e+01, -2.01e+01, -2.43e+01]],
#
#          [[ 1.51e+01,  8.44e+00, -2.16e+01,  1.37e+01,  9.66e+00],
#           [-3.83e+01,  4.16e+00, -3.35e+01, -2.21e+01, -1.08e+01],
#           [-3.32e+01,  4.90e+01,  9.53e-01,  1.10e+01,  6.47e+00],
#           [ 2.06e+00,  1.29e+01, -4.26e+01,  3.84e+00,  9.31e-01],
#           [-3.74e+00,  5.65e+00, -3.39e+01,  1.45e+01,  2.96e+01]],
#
#          [[ 4.25e+00, -1.93e+01, -2.76e+01,  3.26e+01, -3.26e+01],
#           [-3.79e+01, -1.38e+01,  3.00e+01, -3.03e+01,  2.94e+01],
#           [-1.35e+00,  4.96e-01,  4.63e+01,  1.54e+01, -2.76e+01],
#           [-2.26e+01, -1.81e+01, -5.06e+01, -3.29e+00,  1.22e+01],
#           [ 2.36e+01, -5.34e+01,  8.65e+00,  1.72e+01, -1.90e+01]]]],
#        grad_fn=<PermuteBackward0>)
#
# Expected
# tensor([[[[ -6.16,  41.61,   2.97, -16.85, -31.99],
#           [  2.11,  -6.77,  11.99, -23.69,  15.28],
#           [ 10.33,  35.65,   0.97, -21.79, -40.59],
#           [  8.14,  37.61,   9.40, -10.33,  17.34],
#           [ 18.50,  66.52, -23.07,   9.88,  16.83]],
#
#          [[-28.41,  -0.74,  32.45,  -8.37,  -9.16],
#           [-26.72,  -4.14,   5.15, -11.88,  -9.12],
#           [ -0.83,  32.38, -43.54, -35.78, -32.60],
#           [ 27.63,   3.12,  17.29,  -3.59,  -8.37],
#           [ -6.26,   4.66,  -1.00,  -3.20,  21.92]]],
#
#
#         [[[-12.71,   2.04,   1.20,   3.94,  19.14],
#           [ 10.85,   2.20,  16.08, -27.01, -17.78],
#           [ 11.96,   3.79, -12.77,   1.02, -24.62],
#           [ 23.09, -35.46,  10.87, -30.92,   5.41],
#           [  8.28,  -7.99,   3.84,  36.95,  30.62]],
#
#          [[ 38.43,  12.72,   7.62,  -4.79,  19.12],
#           [  1.03, -13.29,  44.52,  13.29,  11.62],
#           [ 19.53,  17.02,  18.50, -16.53, -13.54],
#           [ 16.78, -39.42,  18.02,  -8.52,  17.11],
#           [-40.12, -22.63, -35.69,   3.21, -30.59]]],
#
#
#         [[[ 21.76,  10.13,  15.65,  18.42,  17.35],
#           [-15.81,  13.32,  -6.99,  15.63,   2.90],
#           [-29.30,  -2.39,  -0.91,   4.75, -16.96],
#           [-34.09,   4.11, -10.34,  -2.76,   8.64],
#           [-14.74,  11.64, -33.89,  39.21,   3.73]],
#
#          [[ 10.75,   8.92, -10.80,   6.58,  27.53],
#           [ 16.04,  52.08,  -8.04,  35.79,  -3.33],
#           [-10.23, -32.28,  19.35,   2.74,  30.62],
#           [ 19.04,   8.07,  -9.17, -11.30, -29.95],
#           [  3.08,  -8.45, -15.69, -29.42, -17.44]]],
#
#
#         [[[-23.59,  -9.39,  65.50,  28.84,   8.24],
#           [  5.79,  10.25,  -8.27, -33.38, -15.77],
#           [ 26.46,  13.66,   3.14,  39.24,   8.72],
#           [  2.62, -10.69,   4.21,  13.74,   3.13],
#           [-11.52, -33.77,  -8.28, -33.36, -30.70]],
#
#          [[  3.08,   6.21, -12.89,  -0.18, -18.45],
#           [  0.61, -19.36,  -5.18,   2.37,  10.00],
#           [ 24.01,  49.13,   6.74,   6.50, -19.59],
#           [-25.17,  -3.72,  36.32, -12.10,  45.85],
#           [ -3.89,  -6.68,   2.51,  -6.01,  -2.66]]],
#
#
#         [[[-34.78,  17.49,  -5.21,   0.52, -21.49],
#           [ -5.70,  11.19,  23.41,  10.40,  39.40],
#           [ 32.62,  12.13,  -7.31, -21.99, -28.10],
#           [ -1.79,  39.02,  16.87,  -3.16, -39.11],
#           [  9.21, -38.06, -37.58,  24.47,  22.68]],
#
#          [[  7.53,   3.71,  18.65, -28.94, -21.47],
#           [ 17.28,  -3.54,  52.40,  11.47,  16.20],
#           [ 25.23, -41.95,  25.73,  -2.81, -37.53],
#           [ 20.76, -50.46, -33.24,  -8.57,  -0.26],
#           [-12.48,  17.53,  -3.40,  28.76,  -1.82]]],
#
#
#         [[[ -1.95,  -9.06,  13.01,   2.04,  -4.70],
#           [ 23.16,  14.38,  14.90,  20.31,  12.72],
#           [-34.63,   7.27,   1.15,   1.75,  12.37],
#           [-16.41,   0.09, -24.45,  28.08,  26.13],
#           [-41.80, -17.18, -31.22, -20.16,   6.08]],
#
#          [[ -3.79,   3.21,  40.30, -32.35,  34.72],
#           [ -3.68,  10.20, -60.47,  11.77,  -4.76],
#           [-36.26,  43.68,  -7.19,  13.97, -41.45],
#           [-29.34, -16.64,   2.83, -32.00,  23.40],
#           [ 16.84, -13.01,  -1.58,  27.70,  11.47]]],
#
#
#         [[[ 17.10,  -2.23,  -7.56,  -3.14,  -0.54],
#           [-26.65,  13.54,   1.01,  -3.57, -27.22],
#           [-22.09,  18.51, -20.95, -59.84, -29.27],
#           [-14.04,  38.98,  11.11,  13.54,  -6.67],
#           [ -7.60,  -6.58,   4.93, -23.47,  39.16]],
#
#          [[ 19.37,   5.44,   6.75,  21.70,  -8.82],
#           [-12.63,  32.69,  -7.96,  16.66, -16.77],
#           [-33.02, -40.27, -34.32,  -7.68, -12.70],
#           [ -3.66,  24.59,  40.21,  10.92,   5.21],
#           [-18.92,  17.24, -52.11, -46.01,   2.34]]],
#
#
#         [[[ 15.12,   8.44, -21.60,  13.67,   9.66],
#           [-38.35,   4.16, -33.53, -22.08, -10.77],
#           [-33.18,  48.99,   0.95,  10.97,   6.47],
#           [  2.06,  12.91, -42.58,   3.84,   0.93],
#           [ -3.74,   5.65, -33.86,  14.45,  29.56]],
#
#          [[  4.25, -19.34, -27.61,  32.58, -32.56],
#           [-37.91, -13.84,  29.96, -30.30,  29.43],
#           [ -1.35,   0.50,  46.28,  15.44, -27.60],
#           [-22.64, -18.08, -50.61,  -3.29,  12.20],
#           [ 23.55, -53.40,   8.65,  17.18, -19.03]]]])
#
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.077s
#
# FAILED (failures=1)
# *** TEST PARAMS CONFIGURATION THAT FAILED ***
# shape=(11, 4, 16, 16), args=(8, 5), kwargs={'stride': 2, 'padding': 4, 'dilation': 2, 'groups': 2}
# <unittest.runner.TextTestResult run=2 errors=0 failures=1>

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.Conv2d`

# %%
test_convolution.TestConv2dModule.eval()
# Out:
# test_module (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_module) ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.075s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Max-pooling

# %% [markdown]
# - Téměř nedílnou součástí konvolučních sítí jsou tzv. [pooling vrstvy](https://d2l.ai/chapter_convolutional-neural-networks/pooling.html).
# - Implementujeme si jednu z nejčastějších, tzv. max-pooling.
#
# **Dopředný průchod**
#
# - Vstup $\boldsymbol{x}_n$ rozdělíme na $K \times K$ velké nepřekrávající se oblasti a z každé z nich vypočteme maximum.
# - Abychom replikovali chování `MaxPool2d` knihovny, pro velikost výstupu bude platit
#   $$
#   W' = \left\lfloor\frac{W}{K}\right\rfloor
#   $$
#   tj. případech, kdy velikost vstupu $W$ není dělitelná velikostí okna $K$, nadbytečné hodnoty ve vstupu zahodíme.
#
# **Zpětný průchod**
#
# - Gradient na vstup je
#   - 1 na pozicích odpovídajích pozicím maxim,
#   - 0 na ostatních pozicích.
#
# **Implementace a tipy**
#
# - Oproti možnostem v knihovně PyTorch si redukujeme počet hyperparametrů a ponecháme pouze velikost pooling okolí $K$ pod jménem `kernel_size`.
# - Tento parametr bude celé číslo, tzn. že se omezíme na čtvercové okno o roměru $K \times K$.
# - *Operaci naprogramujte vektorově bez použití cyklů!*
#   - Např. max-pooling vektoru s velikostí okna `kernel_size=2`:
#     ``` python
#     >>> x = torch.tensor([1, 2, 4, 3, 5, 5])
#     >>> x.reshape(3, 2).max(dim=1)
#     (tensor([2, 4, 5]), tensor([1, 0, 0]))
#     ```
#   - U dvourozměrného vstupu je potřeba obdobný reshape provést pro výšku i šířku.
#   - Hodit se může také funkce `torch.transpose`, pomocí které lze posunout přidané dimenze na poslední dvě místa, což umožní reshape na `(..., kernel_size * kernel_size)`.

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.MaxPool2dFunction`

# %%
test_convolution.TestMaxPool2dFunction.eval()
# Out:
# test_function (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_function) ...
# ok
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.057s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.MaxPool2d`

# %%
test_convolution.TestMaxPool2dModule.eval()
# Out:
# test_module (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_module) ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.009s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Operace `Variable.reshape` a vrstva `Flatten`

# %% [markdown]
# - Výstup konvoluce je tvaru $N \times C \times H \times W$.
# - Abychom mohli klasifikovat lineární vrstvou, potřebujeme reshape na $N \times D$, tj. potřebujeme výstup "zploštit" (flatten).
# - Operaci implementujeme obecněji jako libovolný reshape a to přímo do třídy `Variable`.
# - Zpětný průchod je reshape z $N \times D$ zpět na $N \times C \times H \times W$.
# - Vrstva `Flatten` pak provede speciální případ reshape $N \times D_1 \times D_2 \times \ldots \rightarrow N \times D$, kde $D = D_1 \cdot D_2 \cdot \ldots$.

# %% [markdown]
# ### TODO: implementujte metodu `ans.autograd.Variable.reshape`

# %%
test_convolution.TestReshapeVariable.eval()
# Out:
# test_operation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_operation) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.050s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.Flatten`

# %%
test_convolution.TestFlattenModule.eval()
# Out:
# test_module (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_module) ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.008s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # (Bonus) Batch normalizace pro 2D vstupy

# %% [markdown]
# - Pokud máte v knihovně `ans.nn` implementovanou normalizaci dávky pro 1D vstupy z minulého cvičení, můžete ji poměrně jednoduše rozšířit pro 2D vstupy.
# - Tzv. [spatial batchnorm](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html), jak se často 2D varianta normalizace dávky označuje v anglické literatuře, *normalizuje přes jednotlivé kanály vstupu*.
# - To znamená, že vektory $\boldsymbol{\mu}, \boldsymbol{\sigma^2}, \boldsymbol{\gamma}, \boldsymbol{\beta}, \boldsymbol{m}, \boldsymbol{v}^2$ jsou vektory o rozměru $C$.
# - Operaci lze naimplementovat následovně:
#   1. převedení vstupního tensoru $\boldsymbol{x}$ s rozměry $N \times C \times H \times W$ na 2D matici $(N \cdot H \cdot W) \times C$,
#   2. aplikace 1D batch normalizace
#   3. převedení výstupní matice $(N \cdot H \cdot W) \times C$ zpět do tensoru s rozměry $N \times C \times H \times W$.

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.BatchNorm2dFunction`

# %%
test_convolution.TestBatchNorm2dFunction.eval()
# Out:
# test_function (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_function) ...
# ok
# test_implementation (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_implementation) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.014s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>

# %% [markdown]
# ### TODO: implementujte třídu `ans.nn.BatchNorm2d`

# %%
test_convolution.TestBatchNorm2dModule.eval()
# Out:
# test_module (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_module) ...
# ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.012s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Konvoluční síť

# %% [markdown]
# - Konvoluční síť implementuje jako třídu `Backbone(ans.nn.Module)` a bude sloužit jako "páteř" (backbone) pro `ans.classification.AutogradClassifier`.
# - Třída bude mít na vstupu dávku obrázků $N \times C \times H \times W$ a vrátí dávku logitů $N \times K$.
# - Aby procházely testy, backbone musí mít
#   - `__init__(self, in_channels: int, num_classes: int, **kwargs)`, tj. dva poziční parametry
#     1. `in_channels` ... počet kanálů $C$ na vstupu (např. 3 pro RGB)
#     2. `num_classes` ... počet tříd $K$ na výstupu
#   - alespoň jednu konvoluční vrstvu `ans.nn.Conv2d`,
#   - `forward` využívající konvoluční vrstvu.
# - Jelikož hledání ideální konvoluční architektury metodou pokus omyl by mohlo být časově náročné, můžete zkusit např. jednu z následujících
#
#   | název   | architektura                                                                                                             |
#   |---------|--------------------------------------------------------------------------------------------------------------------------|
#   | VGG7    | `CR(64), M(2), CR(128), M(2), CR(256), M(2), CR(512), M(2), CR(512), M(2), LR(512), L(10)`                               |
#   | VGG7BN  | `CNR(64), M(2), CNR(128), M(2), CNR(256), M(2), CNR(512), M(2), CNR(512), M(2), LR(512), L(10)`                          |
#   | ResNet9 | `CNR(64), CNR(128), M(2), res(CNR(128), CNR(128)), CNR(256), M(2), CNR(512), M(2), res(CNR(512), CNR(512)), M(4), L(10)` |
#
#   kde:
#   - `CR(64)` znamená dvourozměrnou konvoluci (`C`) se 64 filtry a biasy následovanou ReLU (`R`); všechny konvoluce mají velikost 3x3,
#   - `CNR(64)` znamená blok konvoluce (`C`) - batch normalizace (`N`) - ReLU (`R`),
#   - `M(2)` znamená max-pooling s oknem o velikosti 2 a krokem 2
#   - `LR(512)` znamená lineární vrstvu (`L`) následovanou ReLU (`R`) s *výstupním* vektorem o rozměru 512
#   - `res(convblock)` značí residuální blok formy `z = x + convblock(x)`
# - Architektury jsou pouze doporučené. Můžete vyvinout i libovolnou jinou.
# - VGG7 je klasická konv. síť inspirovaná architekturou [VGG](https://arxiv.org/abs/1409.1556), je pouze zmenšená na 7 vrstev. VGG7BN k ní přidává batch normalizaci.
# - ResNet9 je architektura, která se dobře umisťuje v benchmarku [Standford DAWNBench](https://dawnd9.sites.stanford.edu/dawnbench) v žebříčku hodnotícím trénovací čas pro dosažení 94 % validační přesnosti. Byla vyvinuta v sérii příspěvků [How to train your ResNet](https://myrtle.ai/learn/how-to-train-your-resnet/), která se zabývala trénováním na CIFAR10. Série již bohužel není dostupná.

# %% [markdown]
# ### TODO: Vytvořte model konvoluční sítě

# %%
class Backbone(ans.nn.Module):
    def __init__(self, in_channels: int, num_classes: int, **kwargs) -> None:
        super().__init__()
        
        # neural network architecture:
        self.features = ans.nn.Sequential(
            # first convolution block
            ans.nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),   # C(64)
            ans.nn.ReLU(),                                              # R
            ans.nn.MaxPool2d(kernel_size=2),                            # M(2)
            
            # second convolution block
            ans.nn.Conv2d(64, 128, kernel_size=3, padding=1),           # C(128)
            ans.nn.ReLU(),                                              # R
            ans.nn.MaxPool2d(kernel_size=2),                            # M(2)
            
            # third convolution block
            ans.nn.Conv2d(128, 256, kernel_size=3, padding=1),          # C(256)
            ans.nn.ReLU(),                                              # R
            ans.nn.MaxPool2d(kernel_size=2),                            # M(2)
            
            # fourth convolution block
            ans.nn.Conv2d(256, 512, kernel_size=3, padding=1),          # C(512)
            ans.nn.ReLU(),                                              # R
            ans.nn.MaxPool2d(kernel_size=2),                            # M(2)
            
            # fifth convolution block
            ans.nn.Conv2d(512, 512, kernel_size=3, padding=1),          # C(512)
            ans.nn.ReLU(),                                              # R
            ans.nn.MaxPool2d(kernel_size=2)                             # M(2)
        )
        
        # linear classifier: LR(512) -> L(num_classes)
        self.classifier = ans.nn.Sequential(
            ans.nn.Linear(512, 512),                                    # L(512)
            ans.nn.ReLU(),                                              # R
            ans.nn.Linear(512, num_classes)                             # L(10)
        )

    def forward(self, x: ans.autograd.Variable) -> ans.autograd.Variable:
        # get features using convolution blocks
        x = self.features(x)
        # flattening before classification
        x = x.reshape(x.data.shape[0], -1)
        # classification
        x = self.classifier(x)
        return x

# %%
test_convolution.TestBackbone.eval(backbone_cls=Backbone)
# Out:
# test_backbone (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_backbone) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.209s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# - Požadavky na a způsob preprocessingu/augmentace jsou téměř totožné s cvičením [`neural_library`](neural_library.ipynb).
# - Jediný rozdíl je, že data vstupující do sítě musejí mít tvar $N \times C \times H \times W$.

# %%
class DataPreprocessor:

    def fit(self, dataset: torchvision.datasets.CIFAR10) -> None:
        pass

    def transform(self, dataset: torchvision.datasets.CIFAR10, train: bool = False) -> torch.utils.data.TensorDataset:
        """
        Converts the dataset to the form (N, C, H, W) and returns TensorDataset.
        
        Args:
            Dataset: A tuple (data, labels) where data is of the form (N, H, W, C).
            train: not used...
        
        Returns:
            TensorDataset with data of the form (N, C, H, W).
        """

        x = torch.from_numpy(dataset.data).float() / 255.0
        # reshape to (N, C, H, W)
        x = x.permute(0, 3, 1, 2)
        y = torch.tensor(dataset.targets)

        return torch.utils.data.TensorDataset(x, y)

# %%
test_convolution.TestDataPreprocessor.eval(preprocessor_cls=DataPreprocessor)
# Out:
# test_preprocess (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_preprocess) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 1.436s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %% [markdown]
# # Trénování klasifikátoru

# %% [markdown]
# - Pro klasifikaci použijte `ans.classification.AutogradClassifier` z minula, kterému jako `backbone` předáte konvoluční "páteř" definovanou výše, např.
#   ``` python
#   backbone = Backbone(3, 10)
#   optimizer = ans.nn.SGD(backbone.parameters(), learning_rate=learning_rate)
#   model = ans.classification.AutogradClassifier(backbone, optimizer)
#   ```
# - Nejlepší model uložte jako
#   ``` python
#   model.save('../output/conv_classifier.pt')
#   ```
# - Pro trénování budete velmi pravděpodobně potřebovat GPU. Na CPU běží konvoluční sítě bohužel velmi pomalu.

# %% [markdown]
# ### TODO: Natrénujte *konvoluční* klasifikátor, který dosáhne alespoň 75 % (bonusově **85 %** a **90 %**) *validační* accuracy.

# %%
ans.utils.seed_everything(0)

num_epochs = 200

# hyperparameters
device = 'cuda'
batch_size = 200
learning_rate = 0.0005
weight_decay = 0.0005

# dataset
train_dataset = torchvision.datasets.CIFAR10(root='../data', train=True, download=True)
val_dataset = torchvision.datasets.CIFAR10(root='../data', train=False, download=True)

# preprocessing
preprocessor = DataPreprocessor()
preprocessor.fit(train_dataset)
train_dataset = preprocessor.transform(train_dataset, train=True)
val_dataset = preprocessor.transform(val_dataset, train=False)

# loadery
train_loader = ans.data.BatchLoader(train_dataset, batch_size=batch_size, shuffle=True, device=device)
val_loader = ans.data.BatchLoader(val_dataset, batch_size=batch_size, shuffle=False, device=device)

# model
num_channels = 3
out_size = 10

backbone = Backbone(num_channels, out_size)
backbone = backbone.to(device=device)
optimizer = ans.nn.Adam(
    parameters=backbone.parameters(),
    learning_rate=learning_rate, 
    weight_decay=weight_decay,
)
model = ans.classification.AutogradClassifier(backbone, optimizer)

# validation before training (check for correctness, loss should be about 2.30)
train_loss, train_acc = ans.classification.validate(model, train_loader)
val_loss, val_acc = ans.classification.validate(model, val_loader)
print(f"after init: train_loss={train_loss:.5f}, train_acc={train_acc:.3f}, val_loss={val_loss:.5f}, val_acc={val_acc:.3f}")
best_val_acc = 0.0

for epoch in range(num_epochs):
    # training
    train_loss, train_acc = ans.classification.train_epoch(model, train_loader, learning_rate=learning_rate)

    # validation
    val_loss, val_acc = ans.classification.validate(model, val_loader)
    print(f"Epoch {epoch + 1}: train_loss={train_loss:.5f}, train_acc={train_acc:.3f}, val_loss={val_loss:.5f}, val_acc={val_acc:.3f}")

    # save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        model.save('../output/conv_classifier.pt')

print(f"Training complete. Best validation accuracy achieved: {best_val_acc:.3f}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# after init: train_loss=2.30306, train_acc=0.100, val_loss=2.30306, val_acc=0.100
# Epoch 1: train_loss=1.77261, train_acc=0.321, val_loss=1.46191, val_acc=0.442
# Epoch 2: train_loss=1.29771, train_acc=0.517, val_loss=1.18771, val_acc=0.571
# Epoch 3: train_loss=1.08724, train_acc=0.606, val_loss=1.07734, val_acc=0.617
# Epoch 4: train_loss=0.96679, train_acc=0.652, val_loss=0.94462, val_acc=0.657
# Epoch 5: train_loss=0.86406, train_acc=0.690, val_loss=0.93693, val_acc=0.674
# Epoch 6: train_loss=0.78755, train_acc=0.720, val_loss=0.85451, val_acc=0.704
# Epoch 7: train_loss=0.72451, train_acc=0.744, val_loss=0.89354, val_acc=0.689
# Epoch 8: train_loss=0.66948, train_acc=0.764, val_loss=0.77175, val_acc=0.734
# Epoch 9: train_loss=0.62139, train_acc=0.779, val_loss=0.77005, val_acc=0.730
# Epoch 10: train_loss=0.58346, train_acc=0.794, val_loss=0.74302, val_acc=0.743
# Epoch 11: train_loss=0.54570, train_acc=0.809, val_loss=0.75015, val_acc=0.740
# Epoch 12: train_loss=0.49890, train_acc=0.825, val_loss=0.76268, val_acc=0.740
# Epoch 13: train_loss=0.47401, train_acc=0.834, val_loss=0.76653, val_acc=0.742
# Epoch 14: train_loss=0.43623, train_acc=0.845, val_loss=0.75278, val_acc=0.749
# Epoch 15: train_loss=0.40653, train_acc=0.856, val_loss=0.79753, val_acc=0.738
# Epoch 16: train_loss=0.38326, train_acc=0.865, val_loss=0.80053, val_acc=0.743
# Epoch 17: train_loss=0.35727, train_acc=0.874, val_loss=0.79341, val_acc=0.755
# Epoch 18: train_loss=0.34286, train_acc=0.878, val_loss=0.80483, val_acc=0.747
# Epoch 19: train_loss=0.32055, train_acc=0.888, val_loss=0.80923, val_acc=0.756
# Epoch 20: train_loss=0.28582, train_acc=0.900, val_loss=0.81480, val_acc=0.752
# Training complete. Best validation accuracy achieved: 0.756

# %%
test_convolution.TestValAccuracy75.eval(preprocessor_cls=DataPreprocessor)
# Out:
# test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc) ...
# Files already downloaded and verified
# Files already downloaded and verified
# ok
# ----------------------------------------------------------------------
# Ran 1 test in 6.749s
#
# OK
# <unittest.runner.TextTestResult run=1 errors=0 failures=0>

# %%
test_convolution.TestValAccuracy85.eval(preprocessor_cls=DataPreprocessor)
# Out:
# test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc) ...
# Files already downloaded and verified
# Files already downloaded and verified
# FAIL
# ======================================================================
# FAIL: test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/TUL-ANS-2024-25/tests/test_convolution.py", line 306, in test_val_acc
#     self.check_val_acc(model, device='cuda')
#   File "/content/TUL-ANS-2024-25/tests/test_convolution.py", line 299, in check_val_acc
#     self.assertGreaterEqual(val_acc, self.min_val_acc)
# AssertionError: 0.7563 not greater than or equal to 0.85
# ----------------------------------------------------------------------
# Ran 1 test in 7.310s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>

# %%
test_convolution.TestValAccuracy90.eval(preprocessor_cls=DataPreprocessor)
# Out:
# test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc) ...
# Files already downloaded and verified
# Files already downloaded and verified
# FAIL
# ======================================================================
# FAIL: test_val_acc (tests.ANSTestCase.eval.<locals>._TestCaseClass.test_val_acc)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/TUL-ANS-2024-25/tests/test_convolution.py", line 306, in test_val_acc
#     self.check_val_acc(model, device='cuda')
#   File "/content/TUL-ANS-2024-25/tests/test_convolution.py", line 299, in check_val_acc
#     self.assertGreaterEqual(val_acc, self.min_val_acc)
# AssertionError: 0.7563 not greater than or equal to 0.9
# ----------------------------------------------------------------------
# Ran 1 test in 6.781s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>
